# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko) and Vadim Shestopalov (@vchulski). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center>Assignment #1. Fall 2019
# ## <center>Exploratory data analysis of Olympic games with Pandas
#
# <img src='../../img/olympic_logo.png' width=50%>

# %% [markdown]
# Prior to working on the assignment, you'd better check out the corresponding course material:
#  - [Exploratory data analysis with Pandas](https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic01_pandas_data_analysis/topic1_pandas_data_analysis.ipynb?flush_cache=true), the same as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas)
#  - first lectures in mlcourse.ai [YouTube playlist ](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
#  - you can also practice with demo assignments, which are simpler and already shared with solutions: [A1 demo](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset), [solution](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset-solution)
#
# ### Your task is to:
#  1. write code and perform computations in the cells below
#  2. choose answers in the [webform](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU). Solutions will be shared only with those who've filled in this form
#  3. submit answers with some email and **remember it**! This will be your ID during the course. Specify your real full name in the form as well (no nicks allowed in the final top-100 [rating](https://mlcourse.ai/rating)). If in doubt, you can re-submit the form till the deadline for A1, no problem, but stick to only one email.
#
# ### <center> Deadline for A1: 2019 September 15, 20:59 GMT (London time)
#
# You'll get up to 10 credits for this assignment.
#
# ### How to get help
# In [ODS Slack](https://opendatascience.slack.com) (if you still don't have access, fill in the [form](https://docs.google.com/forms/d/10HAN5huM996snUKjsNYyT_oOlm2uOsTKulKurb3oiNM/) mentioned on the mlcourse.ai main page), we have a channel **#mlcourse_ai_news** with announcements from the course team.
# You can discuss the course content freely in the **#mlcourse_ai** channel (we still have a huge Russian-speaking group, they have a separate channel **#mlcourse_ai_rus**).
#
# Here's how you reply in a thread (press this dialog icon to drill down into a thread):
#
# <img src="../../img/start_a_thread.png" />
#
# Please stick to special threads *a1_q1-5_fall2019* and *a1_q6-10_fall2019* in **#mlcourse_ai_news** for your questions on A1. Help each other without sharing correct code and answers. Our TA **Vadim @vchulski** is there to help (only in the mentioned thread, do not write to him directly).
#
# Lastly, you can save useful messages by pinning them, further you can find pinned items on the top, just below the channel name:
#
# <img src="../../img/pinned_item.png" />
#
# ### Assignment
# __There are ten questions about 120 years of Olympic history in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU).__

# %% [markdown]
# Download the file `athlete_events.csv` from [here](https://drive.google.com/file/d/1f5v6Z2ayc7h698FG_98wP5x1Y2zZQeox/view?usp=sharing) (scraped by [rgriffin](https://www.randigriffin.com/) from www.sports-reference.com). The dataset has the following features:
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd
import numpy as np

# %%
# Change the path to the dataset file if needed. 
PATH = 'C:\\Users\\bysra\\Downloads\\athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1992 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 16 and 15
# - 14 and 13
# - 13 and 11
# - 11 and 12

# %%
data.Age[data.Sex=='F'][data.Year==1992].min()
# Out:
# 12.0

# %%
data.Age[data.Sex=='M'][data.Year==1992].min()
# Out:
# 11.0

# %% [markdown]
# __2. What was the percentage of male basketball players among all the male participants of the 2012 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0.2
# - 1.5
# - 2.5
# - 7.7

# %%
a=data.loc[(data['Sex']=='M')&(data['Sport']=='Basketball')&(data['Year']==2012)]
a=a.ID.nunique()
b=data.loc[(data['Sex']=='M')&(data['Year']==2012)]
b=b.ID.nunique()
c=a/b*100
print(c)
d=round(c,1)
print(d)
# Out:
# 2.4560805048609926
# 2.5

# %% [markdown]
# __3. What are the mean and standard deviation of height for female tennis players who participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 171.8 and 6.5
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
a=data.loc[(data['Sex']=='F')&(data['Year']==2000)&(data['Sport']=='Tennis')].mean()
a=round(a,1)
print(a)
b=data.loc[(data['Sex']=='F')&(data['Year']==2000)&(data['Sport']=='Tennis')].std()
print(round(b,1))
# Out:
# ID        76328.4
# Age          23.4
# Height      171.8
# Weight       61.5
# Year       2000.0
# dtype: float64
# ID        39698.7
# Age           3.5
# Height        6.5
# Weight        5.9
# Year          0.0
# dtype: float64

# %% [markdown]
# __4. Find a sportsman who participated in the 2006 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - Judo
# - Bobsleigh
# - Skeleton
# - Boxing

# %%
data.Weight[data['Year']==2006].max()
data.Sport[(data['Year']==2006)&(data['Weight']==127)]
# Out:
# 8102    Skeleton
# Name: Sport, dtype: object

# %% [markdown]
# __5. How many times did John Aalberg participate in the Olympics held in different years?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
a=data.loc[data['Name']=='John Aalberg']
a.Year.nunique()
# Out:
# 2

# %% [markdown]
# __6. How many gold medals in tennis did sportspeople from the Switzerland team win at the 2008 Olympics? Count every medal from every sportsperson.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
a=data.loc[(data['Team']=='Switzerland')&(data['Year']==2008)&(data['Medal']=='Gold')]
b=a.Medal.count()
b
# Out:
# 3

# %% [markdown]
# __7. Is it true that Spain won fewer medals than Italy at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes
# - No

# %%
a=data.loc[(data['Team']=='Spain') & (data['Year']==2016)]
x=a.Medal.count()
b=data.loc[(data['Team']=='Italy') & (data['Year']==2016)]
y=b.Medal.count()
if x  <y:
  print("True")
else:
  print("False")
# Out:
# True

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2008 Olympics belong to?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - [45-55] and [25-35) correspondingly
# - [45-55] and [15-25) correspondingly
# - [35-45) and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
x=range(15,25)

s = 0
for n in x :
   a=data.loc[(data['Year']==2008) & (data['Age']==n)]
   b=a.ID.count()
   s+=b
print(s)
# Out:
# 6294

# %%
data['Year_Cut'] = pd.cut(data['Age'], bins = [14.5,24.5,34.5,44.5,55], labels = ["15-25","25-35","35-45","45-55"])

# %%
data.loc[(data['Year']==2008)].groupby("Year_Cut").count()
# Out:
#             ID  Name   Sex   Age  Height  Weight  Team   NOC  Games  Year  \
# Year_Cut
# 15-25     6294  6294  6294  6294    6202    6194  6294  6294   6294  6294
# 25-35     6367  6367  6367  6367    6320    6324  6367  6367   6367  6367
# 35-45      790   790   790   790     780     778   790   790    790   790
# 45-55      119   119   119   119     119     117   119   119    119   119
#
#           Season  City  Sport  Event  Medal
# Year_Cut
# 15-25       6294  6294   6294   6294    881
# 25-35       6367  6367   6367   6367   1042
# 35-45        790   790    790    790    108
# 45-55        119   119    119    119     16

# %%
data[data.Age==15]
# Out:
#             ID                                       Name Sex   Age  Height  \
# 265        137                  Giordano Giulio Abbondati   M  15.0   175.0
# 295        159  Reem Wa'il Abdalazem Abdalazem El-Bossaty   F  15.0   167.0
# 296        159  Reem Wa'il Abdalazem Abdalazem El-Bossaty   F  15.0   167.0
# 600        346     Shaza Yahia Nazih Abdulrahman El-Sayed   F  15.0   170.0
# 710        404                Louis Grenville "Lou" Abell   M  15.0     NaN
# 1020       572                         Rui Pinto de Abreu   M  15.0   177.0
# 1021       572                         Rui Pinto de Abreu   M  15.0   177.0
# 1348       765                             Jean-Paul Adam   M  15.0     NaN
# 1349       765                             Jean-Paul Adam   M  15.0     NaN
# 1350       765                             Jean-Paul Adam   M  15.0     NaN
# 1761       977                        Erik William Adlerz   M  15.0     NaN
# 1768       978           Mrta Elvira Adlerz (-Hermansson)   F  15.0     NaN
# 2317      1290                      Marcelo Vctor Aguirre   M  15.0   174.0
# 3229      1812                     Khaled Anwar Al-Awadhi   M  15.0   170.0
# 3230      1812                     Khaled Anwar Al-Awadhi   M  15.0   170.0
# 3237      1815                      Khodor Munir Al-Aywan   M  15.0   165.0
# 3246      1820             Mohanad Ahmed Dheyaa Al-Azzawi   M  15.0   173.0
# 3421      1937                            Anwar Al-Harazi   M  15.0   170.0
# 4306      2461                   Ana Feio da Gama Alegria   F  15.0   177.0
# 4307      2461                   Ana Feio da Gama Alegria   F  15.0   177.0
# 4633      2640                           runn Alfresdttir   F  15.0     NaN
# 4634      2640                           runn Alfresdttir   F  15.0     NaN
# 4937      2813                           Lesley Allardice   F  15.0   162.0
# 4938      2813                           Lesley Allardice   F  15.0   162.0
# 4939      2813                           Lesley Allardice   F  15.0   162.0
# 4940      2813                           Lesley Allardice   F  15.0   162.0
# 5147      2929                Lynne Marie Allsup (-Olson)   F  15.0   163.0
# 5216      2959                                Lenke Almsi   F  15.0   148.0
# 5217      2959                                Lenke Almsi   F  15.0   148.0
# 5218      2959                                Lenke Almsi   F  15.0   148.0
# ...        ...                                        ...  ..   ...     ...
# 268338  134264        Wiesawa Barbara elaskowska (-Raska)   F  15.0   153.0
# 268339  134264        Wiesawa Barbara elaskowska (-Raska)   F  15.0   153.0
# 268340  134264        Wiesawa Barbara elaskowska (-Raska)   F  15.0   153.0
# 268341  134264        Wiesawa Barbara elaskowska (-Raska)   F  15.0   153.0
# 268342  134264        Wiesawa Barbara elaskowska (-Raska)   F  15.0   153.0
# 268343  134264        Wiesawa Barbara elaskowska (-Raska)   F  15.0   153.0
# 268372  134277                        Svitlana Zelepukina   F  15.0   147.0
# 268373  134277                        Svitlana Zelepukina   F  15.0   147.0
# 268374  134277                        Svitlana Zelepukina   F  15.0   147.0
# 268375  134277                        Svitlana Zelepukina   F  15.0   147.0
# 268376  134277                        Svitlana Zelepukina   F  15.0   147.0
# 268377  134277                        Svitlana Zelepukina   F  15.0   147.0
# 268675  134416                                   Zhan Shu   F  15.0   170.0
# 268676  134416                                   Zhan Shu   F  15.0   170.0
# 268677  134416                                   Zhan Shu   F  15.0   170.0
# 268678  134416                                   Zhan Shu   F  15.0   170.0
# 269080  134638                                 Zhao Guona   F  15.0     NaN
# 269164  134692                Tatyana Ivanovna Zharganova   F  15.0   147.0
# 269165  134692                Tatyana Ivanovna Zharganova   F  15.0   147.0
# 269166  134692                Tatyana Ivanovna Zharganova   F  15.0   147.0
# 269167  134692                Tatyana Ivanovna Zharganova   F  15.0   147.0
# 269328  134768  Nina Alexandrovna Zhivanevskaya Ilichiova   F  15.0   166.0
# 269329  134768  Nina Alexandrovna Zhivanevskaya Ilichiova   F  15.0   166.0
# 269330  134768  Nina Alexandrovna Zhivanevskaya Ilichiova   F  15.0   166.0
# 269484  134845                                Zhu Jinhong   F  15.0   152.0
# 269658  134939                             Miriam Ziegler   F  15.0   154.0
# 269824  135002                             Eileen Zillmer   F  15.0   170.0
# 270856  135462                      Bernadette Zurbriggen   F  15.0   173.0
# 270857  135462                      Bernadette Zurbriggen   F  15.0   173.0
# 270858  135462                      Bernadette Zurbriggen   F  15.0   173.0
#
#         Weight              Team  NOC        Games  Year  Season         City  \
# 265       64.0             Italy  ITA  1964 Winter  1964  Winter    Innsbruck
# 295       60.0             Egypt  EGY  2008 Summer  2008  Summer      Beijing
# 296       60.0             Egypt  EGY  2008 Summer  2008  Summer      Beijing
# 600       59.0             Egypt  EGY  2008 Summer  2008  Summer      Beijing
# 710        NaN  Vesper Boat Club  USA  1900 Summer  1900  Summer        Paris
# 1020      64.0          Portugal  POR  1976 Summer  1976  Summer     Montreal
# 1021      64.0          Portugal  POR  1976 Summer  1976  Summer     Montreal
# 1348       NaN        Seychelles  SEY  1992 Summer  1992  Summer    Barcelona
# 1349       NaN        Seychelles  SEY  1992 Summer  1992  Summer    Barcelona
# 1350       NaN        Seychelles  SEY  1992 Summer  1992  Summer    Barcelona
# 1761       NaN            Sweden  SWE  1908 Summer  1908  Summer       London
# 1768       NaN            Sweden  SWE  1912 Summer  1912  Summer    Stockholm
# 2317      66.0          Paraguay  PAR  2008 Summer  2008  Summer      Beijing
# 3229      61.0            Kuwait  KUW  1980 Summer  1980  Summer       Moskva
# 3230      61.0            Kuwait  KUW  1980 Summer  1980  Summer       Moskva
# 3237      67.0           Lebanon  LIB  1988 Summer  1988  Summer        Seoul
# 3246      65.0              Iraq  IRQ  2012 Summer  2012  Summer       London
# 3421      69.0       North Yemen  YAR  1988 Summer  1988  Summer        Seoul
# 4306      65.0          Portugal  POR  1992 Summer  1992  Summer    Barcelona
# 4307      65.0          Portugal  POR  1992 Summer  1992  Summer    Barcelona
# 4633       NaN           Iceland  ISL  1976 Summer  1976  Summer     Montreal
# 4634       NaN           Iceland  ISL  1976 Summer  1976  Summer     Montreal
# 4937      50.0     Great Britain  GBR  1972 Summer  1972  Summer       Munich
# 4938      50.0     Great Britain  GBR  1972 Summer  1972  Summer       Munich
# 4939      50.0     Great Britain  GBR  1972 Summer  1972  Summer       Munich
# 4940      50.0     Great Britain  GBR  1972 Summer  1972  Summer       Munich
# 5147      59.0     United States  USA  1964 Summer  1964  Summer        Tokyo
# 5216      40.0           Hungary  HUN  1980 Summer  1980  Summer       Moskva
# 5217      40.0           Hungary  HUN  1980 Summer  1980  Summer       Moskva
# 5218      40.0           Hungary  HUN  1980 Summer  1980  Summer       Moskva
# ...        ...               ...  ...          ...   ...     ...          ...
# 268338    45.0            Poland  POL  1980 Summer  1980  Summer       Moskva
# 268339    45.0            Poland  POL  1980 Summer  1980  Summer       Moskva
# 268340    45.0            Poland  POL  1980 Summer  1980  Summer       Moskva
# 268341    45.0            Poland  POL  1980 Summer  1980  Summer       Moskva
# 268342    45.0            Poland  POL  1980 Summer  1980  Summer       Moskva
# 268343    45.0            Poland  POL  1980 Summer  1980  Summer       Moskva
# 268372    40.0           Ukraine  UKR  1996 Summer  1996  Summer      Atlanta
# 268373    40.0           Ukraine  UKR  1996 Summer  1996  Summer      Atlanta
# 268374    40.0           Ukraine  UKR  1996 Summer  1996  Summer      Atlanta
# 268375    40.0           Ukraine  UKR  1996 Summer  1996  Summer      Atlanta
# 268376    40.0           Ukraine  UKR  1996 Summer  1996  Summer      Atlanta
# 268377    40.0           Ukraine  UKR  1996 Summer  1996  Summer      Atlanta
# 268675    59.0             China  CHN  2000 Summer  2000  Summer       Sydney
# 268676    59.0             China  CHN  2000 Summer  2000  Summer       Sydney
# 268677    59.0             China  CHN  2000 Summer  2000  Summer       Sydney
# 268678    59.0             China  CHN  2000 Summer  2000  Summer       Sydney
# 269080     NaN             China  CHN  1994 Winter  1994  Winter  Lillehammer
# 269164    40.0           Belarus  BLR  1996 Summer  1996  Summer      Atlanta
# 269165    40.0           Belarus  BLR  1996 Summer  1996  Summer      Atlanta
# 269166    40.0           Belarus  BLR  1996 Summer  1996  Summer      Atlanta
# 269167    40.0           Belarus  BLR  1996 Summer  1996  Summer      Atlanta
# 269328    56.0      Unified Team  EUN  1992 Summer  1992  Summer    Barcelona
# 269329    56.0      Unified Team  EUN  1992 Summer  1992  Summer    Barcelona
# 269330    56.0      Unified Team  EUN  1992 Summer  1992  Summer    Barcelona
# 269484    45.0             China  CHN  1992 Summer  1992  Summer    Barcelona
# 269658    47.0           Austria  AUT  2010 Winter  2010  Winter    Vancouver
# 269824    49.0      West Germany  FRG  1968 Winter  1968  Winter     Grenoble
# 270856    66.0       Switzerland  SUI  1972 Winter  1972  Winter      Sapporo
# 270857    66.0       Switzerland  SUI  1972 Winter  1972  Winter      Sapporo
# 270858    66.0       Switzerland  SUI  1972 Winter  1972  Winter      Sapporo
#
#                         Sport  \
# 265            Figure Skating
# 295     Synchronized Swimming
# 296     Synchronized Swimming
# 600     Synchronized Swimming
# 710                    Rowing
# 1020                 Swimming
# 1021                 Swimming
# 1348                 Swimming
# 1349                 Swimming
# 1350                 Swimming
# 1761                   Diving
# 1768                   Diving
# 2317             Table Tennis
# 3229                  Fencing
# 3230                  Fencing
# 3237            Weightlifting
# 3246                 Swimming
# 3421                Athletics
# 4306                 Swimming
# 4307                 Swimming
# 4633                 Swimming
# 4634                 Swimming
# 4937                 Swimming
# 4938                 Swimming
# 4939                 Swimming
# 4940                 Swimming
# 5147                 Swimming
# 5216               Gymnastics
# 5217               Gymnastics
# 5218               Gymnastics
# ...                       ...
# 268338             Gymnastics
# 268339             Gymnastics
# 268340             Gymnastics
# 268341             Gymnastics
# 268342             Gymnastics
# 268343             Gymnastics
# 268372             Gymnastics
# 268373             Gymnastics
# 268374             Gymnastics
# 268375             Gymnastics
# 268376             Gymnastics
# 268377             Gymnastics
# 268675               Swimming
# 268676               Swimming
# 268677               Swimming
# 268678               Swimming
# 269080         Figure Skating
# 269164             Gymnastics
# 269165             Gymnastics
# 269166             Gymnastics
# 269167             Gymnastics
# 269328               Swimming
# 269329               Swimming
# 269330               Swimming
# 269484                 Diving
# 269658         Figure Skating
# 269824         Figure Skating
# 270856          Alpine Skiing
# 270857          Alpine Skiing
# 270858          Alpine Skiing
#
#                                                   Event   Medal Year_Cut
# 265                        Figure Skating Men's Singles     NaN    15-25
# 295                  Synchronized Swimming Women's Duet     NaN    15-25
# 296                  Synchronized Swimming Women's Team     NaN    15-25
# 600                  Synchronized Swimming Women's Team     NaN    15-25
# 710                           Rowing Men's Coxed Eights    Gold    15-25
# 1020                Swimming Men's 400 metres Freestyle     NaN    15-25
# 1021      Swimming Men's 4 x 200 metres Freestyle Relay     NaN    15-25
# 1348                Swimming Men's 200 metres Freestyle     NaN    15-25
# 1349                Swimming Men's 400 metres Freestyle     NaN    15-25
# 1350        Swimming Men's 200 metres Individual Medley     NaN    15-25
# 1761                              Diving Men's Platform     NaN    15-25
# 1768                          Diving Women's Plain High     NaN    15-25
# 2317                         Table Tennis Men's Singles     NaN    15-25
# 3229                     Fencing Men's Foil, Individual     NaN    15-25
# 3230                           Fencing Men's Foil, Team     NaN    15-25
# 3237                      Weightlifting Men's Flyweight     NaN    15-25
# 3246                Swimming Men's 100 metres Butterfly     NaN    15-25
# 3421                       Athletics Men's 5,000 metres     NaN    15-25
# 4306              Swimming Women's 100 metres Freestyle     NaN    15-25
# 4307              Swimming Women's 100 metres Butterfly     NaN    15-25
# 4633              Swimming Women's 100 metres Butterfly     NaN    15-25
# 4634              Swimming Women's 200 metres Butterfly     NaN    15-25
# 4937              Swimming Women's 100 metres Freestyle     NaN    15-25
# 4938              Swimming Women's 200 metres Freestyle     NaN    15-25
# 4939    Swimming Women's 4 x 100 metres Freestyle Relay     NaN    15-25
# 4940       Swimming Women's 4 x 100 metres Medley Relay     NaN    15-25
# 5147    Swimming Women's 4 x 100 metres Freestyle Relay    Gold    15-25
# 5216           Gymnastics Women's Individual All-Around     NaN    15-25
# 5217                 Gymnastics Women's Team All-Around     NaN    15-25
# 5218                  Gymnastics Women's Floor Exercise     NaN    15-25
# ...                                                 ...     ...      ...
# 268338         Gymnastics Women's Individual All-Around     NaN    15-25
# 268339               Gymnastics Women's Team All-Around     NaN    15-25
# 268340                Gymnastics Women's Floor Exercise     NaN    15-25
# 268341                   Gymnastics Women's Horse Vault     NaN    15-25
# 268342                   Gymnastics Women's Uneven Bars     NaN    15-25
# 268343                  Gymnastics Women's Balance Beam     NaN    15-25
# 268372         Gymnastics Women's Individual All-Around     NaN    15-25
# 268373               Gymnastics Women's Team All-Around     NaN    15-25
# 268374                Gymnastics Women's Floor Exercise     NaN    15-25
# 268375                   Gymnastics Women's Horse Vault     NaN    15-25
# 268376                   Gymnastics Women's Uneven Bars     NaN    15-25
# 268377                  Gymnastics Women's Balance Beam     NaN    15-25
# 268675           Swimming Women's 100 metres Backstroke     NaN    15-25
# 268676           Swimming Women's 200 metres Backstroke     NaN    15-25
# 268677    Swimming Women's 200 metres Individual Medley     NaN    15-25
# 268678     Swimming Women's 4 x 100 metres Medley Relay     NaN    15-25
# 269080                   Figure Skating Women's Singles     NaN    15-25
# 269164         Gymnastics Women's Individual All-Around     NaN    15-25
# 269165               Gymnastics Women's Team All-Around     NaN    15-25
# 269166                   Gymnastics Women's Uneven Bars     NaN    15-25
# 269167                  Gymnastics Women's Balance Beam     NaN    15-25
# 269328           Swimming Women's 100 metres Backstroke     NaN    15-25
# 269329           Swimming Women's 200 metres Backstroke     NaN    15-25
# 269330     Swimming Women's 4 x 100 metres Medley Relay  Bronze    15-25
# 269484                          Diving Women's Platform     NaN    15-25
# 269658                   Figure Skating Women's Singles     NaN    15-25
# 269824                   Figure Skating Women's Singles     NaN    15-25
# 270856                   Alpine Skiing Women's Downhill     NaN    15-25
# 270857               Alpine Skiing Women's Giant Slalom     NaN    15-25
# 270858                     Alpine Skiing Women's Slalom     NaN    15-25
#
# [2203 rows x 16 columns]

# %%
x=range(35,46)
s = 0
for n in x :
   a=data.loc[(data['Year']==2008) & (data['Age']==n)]
   b=a.ID.count()
   s+=b
print(s)
# Out:
# 818

# %%
a=data.loc[data['Year']==2008]
a.Age.value_counts().sort_values(ascending=False)
# Out:
# ID        14052.5
# Age          19.0
# Height      162.0
# Weight       54.0
# Year       2008.0
# Name: 0.1, dtype: float64

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Atlanta? Is it true that there were Winter Olympics held in Squaw Valley?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes, Yes
# - Yes, No
# - No, Yes
# - No, No

# %%
data.loc[(data['City']=='Atlanta') & (data['Season']=='Summer')]
data.loc[(data['City']=='Squaw Valley') & (data['Season']=='Winter')]
# Out:
#             ID                                       Name Sex   Age  Height  \
# 83          24                           Nils Egil Aaness   M  24.0     NaN
# 84          24                           Nils Egil Aaness   M  24.0     NaN
# 113         40                            Roald Edgar Aas   M  31.0     NaN
# 114         40                            Roald Edgar Aas   M  31.0     NaN
# 115         40                            Roald Edgar Aas   M  31.0     NaN
# 1307       735               Benjamin Maxwell "Ben" Acton   M  32.0     NaN
# 2071      1150                           Sven Ingvar Agge   M  34.0     NaN
# 2856      1586                           Shikashi Akazawa   M  25.0   180.0
# 2909      1621             Charles Arthur "Charlie" Akers   M  20.0   177.0
# 3938      2275                     Toimi Johannes Alatalo   M  30.0   174.0
# 3939      2275                     Toimi Johannes Alatalo   M  30.0   174.0
# 3940      2275                     Toimi Johannes Alatalo   M  30.0   174.0
# 4057      2337                              Bruno Alberti   M  25.0   174.0
# 4058      2337                              Bruno Alberti   M  25.0   174.0
# 4059      2337                              Bruno Alberti   M  25.0   174.0
# 4363      2486         Veniamin Veniaminovich Aleksandrov   M  22.0   180.0
# 5279      2987              Aleksandr Davletovich Almetov   M  20.0   178.0
# 5983      3359                                Paul Ambros   M  25.0   174.0
# 6067      3414                 Ronald William "Ron" Amess   M  22.0     NaN
# 6536      3660                         Osvaldo A. Ancinas   M  25.0     NaN
# 6537      3660                         Osvaldo A. Ancinas   M  25.0     NaN
# 6538      3660                         Osvaldo A. Ancinas   M  25.0     NaN
# 6767      3795         Beverly Marie Anderson (-Brockway)   F  21.0     NaN
# 6768      3795         Beverly Marie Anderson (-Brockway)   F  21.0     NaN
# 6881      3866                       Verne Ralph Anderson   M  22.0     NaN
# 6882      3866                       Verne Ralph Anderson   M  22.0     NaN
# 6883      3866                       Verne Ralph Anderson   M  22.0     NaN
# 6923      3884                      Allan Ejvin Andersson   M  28.0     NaN
# 6924      3885                        ke Anders Andersson   M  23.0   177.0
# 7897      4375                   Nikolay Petrovich Anikin   M  28.0     NaN
# ...        ...                                        ...  ..   ...     ...
# 259093  129707                                Kuno Werner   M  34.0     NaN
# 259094  129707                                Kuno Werner   M  34.0     NaN
# 259095  129707                                Kuno Werner   M  34.0     NaN
# 260492  130359                        Adolf Jakob Wiklund   M  38.0     NaN
# 260665  130439                      Hans Erik Wilhelmsson   M  23.0     NaN
# 261149  130691                 Thomas Mark "Tom" Williams   M  19.0   180.0
# 261497  130844             Joseph Peter "Joe Pete" Wilson   M  24.0     NaN
# 261543  130866                             Mary L. Wilson   F  19.0     NaN
# 262523  131354                              Heinz Wolfram   M  25.0     NaN
# 262524  131354                              Heinz Wolfram   M  25.0     NaN
# 262591  131395           Cecilia Ann Womersley (-Jenkins)   F  16.0     NaN
# 262592  131395           Cecilia Ann Womersley (-Jenkins)   F  16.0     NaN
# 262593  131395           Cecilia Ann Womersley (-Jenkins)   F  16.0     NaN
# 263157  131677                           Bo Sune Wretling   M  21.0     NaN
# 264227  132228               Viktor Prokhorovich Yakushev   M  22.0   171.0
# 264314  132272                           Toshihiko Yamada   M  27.0   165.0
# 265605  132901  Radiya Nikolayevna Yeroshina (-Nurgayeva)   F  29.0     NaN
# 265606  132901  Radiya Nikolayevna Yeroshina (-Nurgayeva)   F  29.0     NaN
# 265709  132949                           Torbjrn Yggeseth   M  25.0     NaN
# 266074  133113                Yevgeny Mikhaylovich Yorkin   M  27.0     NaN
# 266096  133128                              Rikio Yoshida   M  20.0   162.0
# 267657  133907                              Nilo Zandanel   M  22.0   167.0
# 268136  134147                    Lev Sergeyevich Zaytsev   M  22.0   179.0
# 268352  134268                            Kazimierz Zelek   M  22.0   169.0
# 268353  134268                            Kazimierz Zelek   M  22.0   169.0
# 268354  134268                            Kazimierz Zelek   M  22.0   169.0
# 269551  134875         Nina Alekseyevna Zhuk (Bakusheva-)   F  25.0     NaN
# 269552  134876                Stanislav Alekseyevich Zhuk   M  25.0     NaN
# 269864  135022              Josef Egon Norbert Zimmermann   M  27.0     NaN
# 270690  135376                           Ross Barta Zucco   M  25.0     NaN
#
#         Weight            Team  NOC        Games  Year  Season          City  \
# 83         NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 84         NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 113        NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 114        NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 115        NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 1307       NaN       Australia  AUS  1960 Winter  1960  Winter  Squaw Valley
# 2071       NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 2856      77.0           Japan  JPN  1960 Winter  1960  Winter  Squaw Valley
# 2909      73.0   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 3938      67.0         Finland  FIN  1960 Winter  1960  Winter  Squaw Valley
# 3939      67.0         Finland  FIN  1960 Winter  1960  Winter  Squaw Valley
# 3940      67.0         Finland  FIN  1960 Winter  1960  Winter  Squaw Valley
# 4057      75.0           Italy  ITA  1960 Winter  1960  Winter  Squaw Valley
# 4058      75.0           Italy  ITA  1960 Winter  1960  Winter  Squaw Valley
# 4059      75.0           Italy  ITA  1960 Winter  1960  Winter  Squaw Valley
# 4363      81.0    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 5279      83.0    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 5983      76.0         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 6067       NaN       Australia  AUS  1960 Winter  1960  Winter  Squaw Valley
# 6536       NaN       Argentina  ARG  1960 Winter  1960  Winter  Squaw Valley
# 6537       NaN       Argentina  ARG  1960 Winter  1960  Winter  Squaw Valley
# 6538       NaN       Argentina  ARG  1960 Winter  1960  Winter  Squaw Valley
# 6767       NaN   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 6768       NaN   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 6881       NaN          Canada  CAN  1960 Winter  1960  Winter  Squaw Valley
# 6882       NaN          Canada  CAN  1960 Winter  1960  Winter  Squaw Valley
# 6883       NaN          Canada  CAN  1960 Winter  1960  Winter  Squaw Valley
# 6923       NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 6924      72.0          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 7897       NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# ...        ...             ...  ...          ...   ...     ...           ...
# 259093     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 259094     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 259095     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 260492     NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 260665     NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 261149    82.0   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 261497     NaN   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 261543     NaN       Australia  AUS  1960 Winter  1960  Winter  Squaw Valley
# 262523     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 262524     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 262591     NaN     New Zealand  NZL  1960 Winter  1960  Winter  Squaw Valley
# 262592     NaN     New Zealand  NZL  1960 Winter  1960  Winter  Squaw Valley
# 262593     NaN     New Zealand  NZL  1960 Winter  1960  Winter  Squaw Valley
# 263157     NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 264227     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 264314    58.0           Japan  JPN  1960 Winter  1960  Winter  Squaw Valley
# 265605     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 265606     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 265709     NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 266074     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 266096    57.0           Japan  JPN  1960 Winter  1960  Winter  Squaw Valley
# 267657    63.0           Italy  ITA  1960 Winter  1960  Winter  Squaw Valley
# 268136     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 268352    64.0          Poland  POL  1960 Winter  1960  Winter  Squaw Valley
# 268353    64.0          Poland  POL  1960 Winter  1960  Winter  Squaw Valley
# 268354    64.0          Poland  POL  1960 Winter  1960  Winter  Squaw Valley
# 269551     NaN  Soviet Union-1  URS  1960 Winter  1960  Winter  Squaw Valley
# 269552     NaN  Soviet Union-1  URS  1960 Winter  1960  Winter  Squaw Valley
# 269864     NaN         Austria  AUT  1960 Winter  1960  Winter  Squaw Valley
# 270690     NaN   United States  USA  1960 Winter  1960  Winter  Squaw Valley
#
#                        Sport  \
# 83             Speed Skating
# 84             Speed Skating
# 113            Speed Skating
# 114            Speed Skating
# 115            Speed Skating
# 1307              Ice Hockey
# 2071                Biathlon
# 2856              Ice Hockey
# 2909    Cross Country Skiing
# 3938    Cross Country Skiing
# 3939    Cross Country Skiing
# 3940    Cross Country Skiing
# 4057           Alpine Skiing
# 4058           Alpine Skiing
# 4059           Alpine Skiing
# 4363              Ice Hockey
# 5279              Ice Hockey
# 5983              Ice Hockey
# 6067              Ice Hockey
# 6536           Alpine Skiing
# 6537           Alpine Skiing
# 6538           Alpine Skiing
# 6767           Alpine Skiing
# 6768           Alpine Skiing
# 6881           Alpine Skiing
# 6882           Alpine Skiing
# 6883           Alpine Skiing
# 6923    Cross Country Skiing
# 6924              Ice Hockey
# 7897    Cross Country Skiing
# ...                      ...
# 259093  Cross Country Skiing
# 259094              Biathlon
# 259095  Cross Country Skiing
# 260492              Biathlon
# 260665         Speed Skating
# 261149            Ice Hockey
# 261497  Cross Country Skiing
# 261543        Figure Skating
# 262523         Speed Skating
# 262524         Speed Skating
# 262591         Alpine Skiing
# 262592         Alpine Skiing
# 262593         Alpine Skiing
# 263157            Ice Hockey
# 264227            Ice Hockey
# 264314            Ice Hockey
# 265605  Cross Country Skiing
# 265606  Cross Country Skiing
# 265709           Ski Jumping
# 266074            Ice Hockey
# 266096       Nordic Combined
# 267657           Ski Jumping
# 268136         Speed Skating
# 268352  Cross Country Skiing
# 268353  Cross Country Skiing
# 268354  Cross Country Skiing
# 269551        Figure Skating
# 269552        Figure Skating
# 269864         Alpine Skiing
# 270690         Speed Skating
#
#                                                     Event   Medal
# 83                         Speed Skating Men's 500 metres     NaN
# 84                       Speed Skating Men's 1,500 metres     NaN
# 113                      Speed Skating Men's 1,500 metres    Gold
# 114                      Speed Skating Men's 5,000 metres     NaN
# 115                     Speed Skating Men's 10,000 metres     NaN
# 1307                          Ice Hockey Men's Ice Hockey     NaN
# 2071                         Biathlon Men's 20 kilometres     NaN
# 2856                          Ice Hockey Men's Ice Hockey     NaN
# 2909             Cross Country Skiing Men's 15 kilometres     NaN
# 3938             Cross Country Skiing Men's 15 kilometres     NaN
# 3939             Cross Country Skiing Men's 30 kilometres     NaN
# 3940    Cross Country Skiing Men's 4 x 10 kilometres R...    Gold
# 4057                         Alpine Skiing Men's Downhill     NaN
# 4058                     Alpine Skiing Men's Giant Slalom     NaN
# 4059                           Alpine Skiing Men's Slalom     NaN
# 4363                          Ice Hockey Men's Ice Hockey  Bronze
# 5279                          Ice Hockey Men's Ice Hockey  Bronze
# 5983                          Ice Hockey Men's Ice Hockey     NaN
# 6067                          Ice Hockey Men's Ice Hockey     NaN
# 6536                         Alpine Skiing Men's Downhill     NaN
# 6537                     Alpine Skiing Men's Giant Slalom     NaN
# 6538                           Alpine Skiing Men's Slalom     NaN
# 6767                   Alpine Skiing Women's Giant Slalom     NaN
# 6768                         Alpine Skiing Women's Slalom     NaN
# 6881                         Alpine Skiing Men's Downhill     NaN
# 6882                     Alpine Skiing Men's Giant Slalom     NaN
# 6883                           Alpine Skiing Men's Slalom     NaN
# 6923             Cross Country Skiing Men's 30 kilometres     NaN
# 6924                          Ice Hockey Men's Ice Hockey     NaN
# 7897             Cross Country Skiing Men's 15 kilometres     NaN
# ...                                                   ...     ...
# 259093           Cross Country Skiing Men's 15 kilometres     NaN
# 259094                       Biathlon Men's 20 kilometres     NaN
# 259095  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN
# 260492                       Biathlon Men's 20 kilometres     NaN
# 260665                     Speed Skating Men's 500 metres     NaN
# 261149                        Ice Hockey Men's Ice Hockey    Gold
# 261497           Cross Country Skiing Men's 30 kilometres     NaN
# 261543                     Figure Skating Women's Singles     NaN
# 262523                   Speed Skating Men's 5,000 metres     NaN
# 262524                  Speed Skating Men's 10,000 metres     NaN
# 262591                     Alpine Skiing Women's Downhill     NaN
# 262592                 Alpine Skiing Women's Giant Slalom     NaN
# 262593                       Alpine Skiing Women's Slalom     NaN
# 263157                        Ice Hockey Men's Ice Hockey     NaN
# 264227                        Ice Hockey Men's Ice Hockey  Bronze
# 264314                        Ice Hockey Men's Ice Hockey     NaN
# 265605         Cross Country Skiing Women's 10 kilometres  Bronze
# 265606  Cross Country Skiing Women's 3 x 5 kilometres ...  Silver
# 265709          Ski Jumping Men's Normal Hill, Individual     NaN
# 266074                        Ice Hockey Men's Ice Hockey  Bronze
# 266096                   Nordic Combined Men's Individual     NaN
# 267657          Ski Jumping Men's Normal Hill, Individual     NaN
# 268136                   Speed Skating Men's 1,500 metres     NaN
# 268352           Cross Country Skiing Men's 15 kilometres     NaN
# 268353           Cross Country Skiing Men's 30 kilometres     NaN
# 268354  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN
# 269551                         Figure Skating Mixed Pairs     NaN
# 269552                         Figure Skating Mixed Pairs     NaN
# 269864                       Alpine Skiing Men's Downhill     NaN
# 270690                  Speed Skating Men's 10,000 metres     NaN
#
# [1116 rows x 15 columns]

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1986 Olympics and 2002 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 3
# - 10
# - 15
# - 27

# %%
a=data.loc[data['Year']==2002,'Sport'].nunique()
a
# Out:
# 15

# %% [markdown]
# That's it! Now go and do 30 push-ups! :)
